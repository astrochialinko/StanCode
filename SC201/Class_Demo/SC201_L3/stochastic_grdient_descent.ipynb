# %%
#  File: stochastic_gradient_descent.ipynb
#  ----------------------------
#  This file shows student the fundamental concepts of 
#  machine learing:
#      - loss function
#      - cost function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the L2 loss which is 
# ----------------------------------------
# [(theta*x+b - y)^2]
# ----------------------------------------
# of data (x, y) to the line y = theta*x + b
# 
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x=0
# x: float, 1 data point
# y: float, 1 data point
# return: float, the L2 loss of 1 data point

def cost_function(theta, b, x, y):
    return (theta*x+b-y)**2

# %%
# You should see 0.25
print(cost_function(0.5, 1.5, 2, 2))
# Out:
# 0.25

# %%
# This function returns the partial derivative of L2 loss function
# with respect to theta: 
# --------------------------------------
# 2(theta*x+b - y)*x
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x=0
# x: float, 1 data point
# y: float, 1 data point
# return: float, the dJ_dtheta of 1 data point

def dJ_dtheta(theta, b, x, y):
    return 2*(theta*x+b-y)*x

# %%
# You should see 2.0
print(dJ_dtheta(0.5, 1.5, 2, 2))
# Out:
# 2.0

# %%
# This function returns the partial derivative of L2 loss function
# with respect to b: 
# --------------------------------------
# 2(theta*x+b - y)
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x=0
# x: float, 1 data point
# y: float, 1 data point
# return: float, the dJ_db of 1 data point

def dJ_db(theta, b, x, y):
    return 2*(theta*x+b-y)

# %%
# You should see 1.0
print(dJ_db(0.5, 1.5, 2, 2))
# Out:
# 1.0

# %%
# ---------- DO NOT EDIT THE CODE BELOW THIS LINE ---------- #

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = 3
b = 1

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01

# %%
# ---------- Training process ---------- #
# ---- 11 iterations over all data ----- #

# %%
theta_history = []
b_history = []
cost_history = []
# In SGD, we name 'iteration' as 'epoch'!
for epoch in range(110):
    theta_history.append(theta)
    b_history.append(b)
    
    for i in range(len(x)):
        
        cost = cost_function(theta, b, x[i], y[i])
        cost_history.append(cost)

168781108, 8.311025483490262, 0.09401524682551744, 38.71499788907857, 58.50558126739995, 23.2426470252912, 2.5919958167748747, 4.451025863549287, 54.092827296167584, 85.63536910745145, 7.315066093994627, 8.25475308139326, 3.7165497578927655, 3.23371770684388, 9.846661738252285, 0.5110515712339528, 1.812096821617294, 1.8981905186224477, 10.254873604630175, 16.30846580475772, 1.2417057528475945, 0.24817242252634716, 8.006986888048036, 0.03778141270212073, 37.802808226431445, 57.6507897723016, 22.325243572340952, 2.3383203645288844, 4.4376290061937045, 50.59405354011984, 80.59371818696196, 7.349852006423108, 7.677376260563971, 3.9074259807063436, 3.1200033426337406, 9.508801399767975, 0.44820504893559027, 1.7091413505030835, 1.7951497200817885, 10.334828342744608, 16.565998150424864, 0.9383800309332905, 0.3658969032982608, 7.720854718668864, 0.007530249737283766, 36.93859456351279, 56.8372942354516, 21.4631635096466, 2.107408651068705, 4.424805771109127, 47.34994126850449, 75.90438432376403, 7.383275145030473, 7.143553381656197, 4.094886243553218, 3.0129077540139524, 9.190466178669382, 0.3918299676075001, 1.6132750148910113, 1.6990742981082267, 10.411764199266436, 16.814761861725067, 0.687424790998634, 0.5001324980731281, 7.451456324510869, 0.0002678314581865815, 36.11954271414164, 56.062906027779114, 20.6527101431255, 1.8973239431357758, 4.412530871649624, 44.34104274756021, 71.54113761541643, 7.415385651102959, 6.649887830609668, 4.278708131791 ...

# %%
theta = theta_history[0]
b = b_history[0]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("0 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 3, b = 1

# %%
theta = theta_history[1]
b = b_history[1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.48670475866039, b = 0.5027704401949543

# %%
theta = theta_history[2]
b = b_history[2]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.5481806170005081, b = 0.11108892386970053

# %%
theta = theta_history[3]
b = b_history[3]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.6071112028048695, b = -0.2643758818119817

# %%
theta = theta_history[4]
b = b_history[4]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.6636018974777538, b = -0.6242953940427246

# %%
theta = theta_history[5]
b = b_history[5]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 epoch", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.7177537193384633, b = -0.9693132314648595

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(cost_history)))
plot_y = cost_history
plt.plot(plot_x, plot_y)
plt.title("Errors over epochs", color = 'blue')
# Out:
# Text(0.5, 1.0, 'Errors over epochs')

# %%
if b > 0:
    print(f'############ Final equation: y = {theta_history[-1]}x+{b} ############')
else:
    print(f'############ Final equation: y = {theta_history[-1]}x{b} ############')
# Out:
# ############ Final equation: y = 1.9560980316231151x-0.9693132314648595 ############

# %%
theta = theta_history[-1]
b = b_history[-1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("Final Model", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.9560980316231151, b = -8.859184004556035
